# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch
import torch.nn as nn

# %%
df = pd.read_csv('bank_churn_data.csv')
df
# Out:
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...        ...         ...             ...          ...       ...     ...
# 165029  165029    15667085            Meng          667     Spain  Female
# 165030  165030    15665521       Okechukwu          792    France    Male
# 165031  165031    15664752            Hsia          565    France    Male
# 165032  165032    15689614          Hsiung          554     Spain  Female
# 165033  165033    15732798         Ulyanov          850    France    Male
#
#          Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       33.0       3       0.00              2          1               0
# 1       33.0       1       0.00              2          1               1
# 2       40.0      10       0.00              2          1               0
# 3       34.0       2  148882.54              1          1               1
# 4       33.0       5       0.00              2          1               1
# ...      ...     ...        ...            ...        ...             ...
# 165029  33.0       2       0.00              1          1               1
# 165030  35.0       3       0.00              1          0               0
# 165031  31.0       5       0.00              1          1               1
# 165032  30.0       7  161533.00              1          0               1
# 165033  31.0       1       0.00              1          1               0
#
#         EstimatedSalary  Exited
# 0             181449.97       0
# 1              49503.50       0
# 2             184866.69       0
# 3              84560.88       0
# 4              15068.83       0
# ...                 ...     ...
# 165029        131834.75       0
# 165030        131834.45       0
# 165031        127429.56       0
# 165032         71173.03       0
# 165033         61581.79       1
#
# [165034 rows x 14 columns]

# %% [markdown]
# # Data exploration

# %%
df.dtypes
# Out:
# id                   int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df = df.drop(['id', 'CustomerId', 'Surname'], axis=1)
df
# Out:
#         CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0               668    France    Male  33.0       3       0.00              2
# 1               627    France    Male  33.0       1       0.00              2
# 2               678    France    Male  40.0      10       0.00              2
# 3               581    France    Male  34.0       2  148882.54              1
# 4               716     Spain    Male  33.0       5       0.00              2
# ...             ...       ...     ...   ...     ...        ...            ...
# 165029          667     Spain  Female  33.0       2       0.00              1
# 165030          792    France    Male  35.0       3       0.00              1
# 165031          565    France    Male  31.0       5       0.00              1
# 165032          554     Spain  Female  30.0       7  161533.00              1
# 165033          850    France    Male  31.0       1       0.00              1
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0               1               0        181449.97       0
# 1               1               1         49503.50       0
# 2               1               0        184866.69       0
# 3               1               1         84560.88       0
# 4               1               1         15068.83       0
# ...           ...             ...              ...     ...
# 165029          1               1        131834.75       0
# 165030          0               0        131834.45       0
# 165031          1               1        127429.56       0
# 165032          0               1         71173.03       0
# 165033          1               0         61581.79       1
#
# [165034 rows x 11 columns]

# %%
df2 = df

# %%
map_dict = {'Female' : 0, 'Male' : 1}
df2['Gender'] = df2['Gender'].map(map_dict).astype(int)

# %%
df2['Gender'].value_counts()
# Out:
# 1    93150
# 0    71884
# Name: Gender, dtype: int64

# %%
df2['Geography'].value_counts()
# Out:
# France     94215
# Spain      36213
# Germany    34606
# Name: Geography, dtype: int64

# %%
map_dict = {'France' : 0, 'Spain' : 1, 'Germany' : 2}
df2['Geography'] = df2['Geography'].map(map_dict).astype(int)

# %%
#sns.pairplot(df2, hue="Exited")

# %%
for column in df2.columns:
    plt.figure(figsize=(6, 4))
    plt.hist(df2[column], bins=10)
    plt.title(f'Histogram of {column}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

# %%
df2['Balance'].value_counts()
# Out:
# 0.00         89648
# 124577.33       88
# 127864.40       64
# 122314.50       63
# 129855.32       59
#              ...
# 125824.21        1
# 158741.56        1
# 126815.52        1
# 61172.57         1
# 110993.29        1
# Name: Balance, Length: 30075, dtype: int64

# %%
df2['Balance'].describe()
# Out:
# count    165034.000000
# mean      55478.086689
# std       62817.663278
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%      119939.517500
# max      250898.090000
# Name: Balance, dtype: float64

# %%
df2_balance = df2[df2['Balance'] == 0]
df2_balance
# Out:
#         CreditScore  Geography  Gender   Age  Tenure  Balance  NumOfProducts  \
# 0               668          0       1  33.0       3      0.0              2
# 1               627          0       1  33.0       1      0.0              2
# 2               678          0       1  40.0      10      0.0              2
# 4               716          1       1  33.0       5      0.0              2
# 8               676          0       1  43.0       4      0.0              2
# ...             ...        ...     ...   ...     ...      ...            ...
# 165028          630          0       1  50.0       8      0.0              2
# 165029          667          1       0  33.0       2      0.0              1
# 165030          792          0       1  35.0       3      0.0              1
# 165031          565          0       1  31.0       5      0.0              1
# 165033          850          0       1  31.0       1      0.0              1
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0               1               0        181449.97       0
# 1               1               1         49503.50       0
# 2               1               0        184866.69       0
# 4               1               1         15068.83       0
# 8               1               0        142917.13       0
# ...           ...             ...              ...     ...
# 165028          1               1          5962.50       0
# 165029          1               1        131834.75       0
# 165030          0               0        131834.45       0
# 165031          1               1        127429.56       0
# 165033          1               0         61581.79       1
#
# [89648 rows x 11 columns]

# %%
df2_balance['CreditScore'].plot(kind='hist', bins=20, title='CreditScore')
# Out:
# <Axes: title={'center': 'CreditScore'}, ylabel='Frequency'>

# %%
df2_balance['Exited'].plot(kind='hist', bins=20, title='Exited')
# Out:
# <Axes: title={'center': 'Exited'}, ylabel='Frequency'>

# %%
correlation_matrix = df2.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, cmap='Blues', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data preprocessing

# %%
X = df.iloc[:, 0:10]
y = df.iloc[:, 10]
X
# Out:
#         CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0               668          0       1  33.0       3       0.00
# 1               627          0       1  33.0       1       0.00
# 2               678          0       1  40.0      10       0.00
# 3               581          0       1  34.0       2  148882.54
# 4               716          1       1  33.0       5       0.00
# ...             ...        ...     ...   ...     ...        ...
# 165029          667          1       0  33.0       2       0.00
# 165030          792          0       1  35.0       3       0.00
# 165031          565          0       1  31.0       5       0.00
# 165032          554          1       0  30.0       7  161533.00
# 165033          850          0       1  31.0       1       0.00
#
#         NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0                   2          1               0        181449.97
# 1                   2          1               1         49503.50
# 2                   2          1               0        184866.69
# 3                   1          1               1         84560.88
# 4                   2          1               1         15068.83
# ...               ...        ...             ...              ...
# 165029              1          1               1        131834.75
# 165030              1          0               0        131834.45
# 165031              1          1               1        127429.56
# 165032              1          0               1         71173.03
# 165033              1          1               0         61581.79
#
# [165034 rows x 10 columns]

# %%
## Encoding categorical data
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# Convert categorical label to binary numerical label
LabelEncoder = LabelEncoder()
X = X.copy()

# Encododing the label.
X['Geography'] = LabelEncoder.fit_transform(X['Geography'])
X['Gender'] = LabelEncoder.fit_transform(X['Gender'])
X

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 165029    0
# 165030    0
# 165031    0
# 165032    0
# 165033    1
# Name: Exited, Length: 165034, dtype: int64

# %%
print(type(X))
print(type(y))
print(X.shape)
print(y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (165034, 10)
# (165034,)

# %%
# Convert Pandas to Numpy array
X = X.values
y = y.values

print(type(X))
print(type(y))
print(X.shape)
print(y.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (165034, 10)
# (165034,)

# %%
# Convert Numpy array to Tensor
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)
print(type(X))
print(type(y))
print(X.shape)
print(y.shape)
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# torch.Size([165034, 10])
# torch.Size([165034])

# %%
random_state = 123

# Split the training data set to training (70%) and testing set (30%)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    random_state=random_state
)

print(X_train.dtype)

#  Split the testing data set for validation (50%) and test (50%)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=random_state)
# Out:
# torch.float32

# %%
# Check the size and type of datasets after the splitting
print("Training set")
print(X_train.dtype, X_train.shape)
print(y_train.dtype, y_train.shape)

print("Validation set")
print(X_val.dtype, X_val.shape)
print(y_val.dtype, y_val.shape)

print("Testing set")
print(X_test.dtype, X_test.shape)
print(y_test.dtype, y_test.shape)
# Out:
# Training set
# torch.float32 torch.Size([115523, 10])
# torch.float32 torch.Size([115523])
# Validation set
# torch.float32 torch.Size([24756, 10])
# torch.float32 torch.Size([24756])
# Testing set
# torch.float32 torch.Size([24755, 10])
# torch.float32 torch.Size([24755])

# %%
# Import Smote
from imblearn.over_sampling import SMOTE

# create the instance of SMOTE
smote = SMOTE(random_state=random_state)

# Resampling the X and Y training dataset with SMOTE to handle imbalance dataset
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# Check the size and type of datasets after the splitting
print("Training set")
print(X_train.dtype, X_train.shape)
print(y_train.dtype, y_train.shape)

print("Training set (Smote)")
print(X_train_smote.dtype, X_train_smote.shape)
print(y_train_smote.dtype, y_train_smote.shape)

print("Validation set")
print(X_val.dtype, X_val.shape)
print(y_val.dtype, y_val.shape)

print("Testing set")
print(X_test.dtype, X_test.shape)
print(y_test.dtype, y_test.shape)
# Out:
# Training set
# torch.float32 torch.Size([115523, 10])
# torch.float32 torch.Size([115523])
# Training set (Smote)
# float32 (182382, 10)
# float32 (182382,)
# Validation set
# torch.float32 torch.Size([24756, 10])
# torch.float32 torch.Size([24756])
# Testing set
# torch.float32 torch.Size([24755, 10])
# torch.float32 torch.Size([24755])

# %% [markdown]
# # Data Scaling

# %%
# Normalization
from sklearn.preprocessing import MinMaxScaler
normal_scaler = MinMaxScaler()

# Normalize X variables
X_train_smote_normalized = normal_scaler.fit_transform(X_train_smote)
X_val_normalized = normal_scaler.transform(X_val)
X_test_normalized = normal_scaler.transform(X_test)

# %%
# Convert to Tensor and rename the X variables
X_train = X_train_smote_normalized = torch.tensor(X_train_smote_normalized, dtype=torch.float32)
X_val = X_val_normalized = torch.tensor(X_val_normalized, dtype=torch.float32)
X_test = X_test_normalized = torch.tensor(X_test_normalized, dtype=torch.float32)

# Move y_train_smote to y_train
y_train = torch.tensor(y_train_smote, dtype=torch.float32)

# %%
# Check the size and type of datasets after the splitting

print("Training set (SMOTE)")
print(X_train.dtype, X_train.shape)
print(y_train.dtype, y_train.shape)

print("Validation set")
print(X_val.dtype, X_val.shape)
print(y_val.dtype, y_val.shape)

print("Testing set")
print(X_test.dtype, X_test.shape)
print(y_test.dtype, y_test.shape)
# Out:
# Training set (SMOTE)
# torch.float32 torch.Size([182382, 10])
# torch.float32 torch.Size([182382])
# Validation set
# torch.float32 torch.Size([24756, 10])
# torch.float32 torch.Size([24756])
# Testing set
# torch.float32 torch.Size([24755, 10])
# torch.float32 torch.Size([24755])

# %%
# Increase the dimension of all label variables
y_train = y_train.unsqueeze(1)
y_test = y_test.unsqueeze(1)
y_val = y_val.unsqueeze(1)

# Final check the datasets before feeding them to the model
print("Training set")
print(X_train.dtype, X_train.shape, type(X_train))
print(y_train.dtype, y_train.shape, type(y_train))

print("Validation set")
print(X_val.dtype, X_val.shape, type(X_val))
print(y_val.dtype, y_val.shape, type(y_val))

print("Testing set")
print(X_test.dtype, X_test.shape, type(X_train))
print(y_test.dtype, y_test.shape, type(y_train))
# Out:
# Training set
# torch.float32 torch.Size([182382, 10]) <class 'torch.Tensor'>
# torch.float32 torch.Size([182382, 1]) <class 'torch.Tensor'>
# Validation set
# torch.float32 torch.Size([24756, 10]) <class 'torch.Tensor'>
# torch.float32 torch.Size([24756, 1]) <class 'torch.Tensor'>
# Testing set
# torch.float32 torch.Size([24755, 10]) <class 'torch.Tensor'>
# torch.float32 torch.Size([24755, 1]) <class 'torch.Tensor'>

# %%
# To make sure we conduct a fair comparison between PyTorch and MatLab, We will use the same datasets to train, validate, and test the model on both 2 platforms
# I exported these tensors to CSV files and will upload them for training, validating, and testing in MATLAB.
# Please note that we don't need to run this block anymore. We need it only for the preprocessing of the data. 
# So, I freeze this block of code.

# Convert 6 datasets from Tensor back to Numpy
#X_train_ndarray = X_train.numpy()
#X_test_ndarray = X_test.numpy()
#X_val_ndarray = X_val.numpy()
#y_train_ndarray = y_train.numpy()
#y_test_ndarray = y_test.numpy()
#y_val_ndarray = y_val.numpy()

# Save all datasets to CSV file
#np.savetxt('X_train_ndarray.csv', X_train_ndarray, delimiter=',')
#np.savetxt('X_test_ndarray.csv', X_test_ndarray, delimiter=',')
#np.savetxt('X_val_ndarray.csv', X_val_ndarray, delimiter=',')
#np.savetxt('y_train_ndarray.csv', y_train_ndarray, delimiter=',')
#np.savetxt('y_test_ndarray.csv', y_test_ndarray, delimiter=',')
#np.savetxt('y_val_ndarray.csv', y_val_ndarray, delimiter=',')

# %% [markdown]
# # Neural Network model (Class)

# %%
# Define the structure of the Neural network model
input_features = 10
output_features = 1

# Define hyperparameters for using in grid search to find the best combination
learning_rates_grid = [0.3, 0.2, 0.1, 0.01, 0.001, 0.0001]
hidden_neurons_grid = [2, 4, 7, 10, 20, 30, 50, 100, 200]

# The number of epochs
number_of_epochs = 1000

# Define the null variables to prepare for storing the result of the model
best_accuracy = 0.0
best_hyperparameters = {}

# Define the empty list to store the result of every combination of hyperparameters
learning_rates_list_heatmap = []
hidden_neurons_list_heatmap = []
accuracy_list_heatmap = []

# %%
# Build the class for Neural network model
class Credit_Churn_NN_Model(nn.Module):
    def __init__(self, input_features, hidden_neurons, output_features):
        super(Credit_Churn_NN_Model, self).__init__()
        self.fc1 = nn.Linear(input_features, hidden_neurons)
        self.fc2 = nn.Linear(hidden_neurons, output_features)
        self.sigmoid = nn.Sigmoid()
        self.relu = nn.ReLU()

    def forward(self, x):
        output_layer1 = self.fc1(x)
        l1_activated = self.relu(output_layer1)
        output_layer2 = self.fc2(l1_activated)
        output_activated = self.sigmoid(output_layer2)
        return output_activated

# %%
# Build the function for the model
def train_NN_model(learning_rate, hidden_neurons, X_train, y_train, X_val, y_val, number_of_epochs):
    model = Credit_Churn_NN_Model(input_features, hidden_neurons, output_features)
    criterion = torch.nn.BCELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    # Define value holder for plotting in the graph
    plot_train_loss = []
    plot_val_loss = []

    # Iterate the model e time. e start from 0 to number_of_epochs - 1
    for e in range(number_of_epochs):
        # Training the model
        model.train()
        optimizer.zero_grad()
        y_train_pred = model(X_train)
        train_loss = criterion(y_train_pred, y_train)
        train_loss.backward()
        optimizer.step()
        # append the loss value (Train) to the value holder
        plot_train_loss.append(train_loss)

        # Validation the model
        model.eval()
        with torch.no_grad():
            y_val_pred = model(X_val)
            val_loss = criterion(y_val_pred, y_val)
            # append the loss value (Validation) to the value holder
            plot_val_loss.append(val_loss)

    return model, plot_train_loss, plot_val_loss

# %% [markdown]
# # Fitting the model

# %%
# We will prepare the running time between Pytorch and MatLab
import time
# Start the timer
start_time = time.time()

# Grid search
for learning_rate in learning_rates_grid:
    for hidden_neurons in hidden_neurons_grid:
        print(f"Grid search > training the NNet model with learning rate={learning_rate} and hidden_neurons={hidden_neurons}")
        # Call the function to train and evaluate the model with the nested loop
        trained_model, train_loss, val_loss = train_NN_model(learning_rate, hidden_neurons, X_train, y_train, X_val, y_val, number_of_epochs)

        # After calling the train_NN_model() function, We'll get the trained model
        # We will evaluate the performance of this model by feeding X trained to the trained model

        # Preduct y from the X_train
        y_train_pred = (trained_model(X_train).detach().numpy() > 0.5).astype(int)
        # Calculate the accuracy rate of the model
        accuracy = (y_train_pred == y_train.numpy()).mean()
        #accuracy = (y_train_pred == y_train.numpy()).sum()/len(y_train)
        print(f"Accuracy rate is {accuracy}")
        
        # Store the results in lists
        learning_rates_list_heatmap.append(learning_rate)
        hidden_neurons_list_heatmap.append(hidden_neurons)
        accuracy_list_heatmap.append(accuracy)

        # Check if the current hyperparameters yield a better performance
        if accuracy > best_accuracy: # if Yes
            best_accuracy = accuracy # Then reassign this hyperparameter's accuracy to the best_accuracy variable
            # And replace the best_hyperparameters with the new Lr and Neurons
            best_hyperparameters = {'learning_rate': learning_rate, 'hidden_neurons': hidden_neurons}
            # And replace the plot variable
            train_loss_for_plotting = train_loss
            val_loss_for_plotting = val_loss
            # And replace the model with the best model
            best_model = trained_model

# After the final of nested loop, print the highest one
print("\nThe Best Hyperparameters are ", best_hyperparameters)

# Stop the timer
end_time = time.time()
# Calculate the total time of running code
Total_time = end_time - start_time

print(f"Total time taken: {Total_time} seconds")
# Out:
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=2
# Accuracy rate is 0.7691055038326151
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=4
# Accuracy rate is 0.7628494039982016
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=7
# Accuracy rate is 0.7734315886436162
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=10
# Accuracy rate is 0.799963812218311
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=20
# Accuracy rate is 0.7899079953065544
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=30
# Accuracy rate is 0.8119057801756753
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=50
# Accuracy rate is 0.8045146999155618
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=100
# Accuracy rate is 0.8222741279292912
# Grid search > training the NNet model with learning rate=0.3 and hidden_neurons=200
# Accuracy rate is 0.8089285126821726
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=2
# Accuracy rate is 0.7604697832022898
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=4
# Accuracy rate is 0.7609303549692403
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=7
# Accuracy rate is 0.7612922327861302
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=10
# Accuracy rate is 0.7707504030002961
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=20
# Accuracy rate is 0.7704433551556623
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=30
# Accuracy rate is 0.7830597317717757
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=50
# Accuracy rate is 0.7823798401158009
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=100
# Accuracy rate is 0.7914925815047538
# Grid search > training the NNet model with learning rate=0.2 and hidden_neurons=200
# Accuracy rate is 0.7932910045947517
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=2
# Accuracy rate is 0.7523604303056223
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=4
# Accuracy rate is 0.7436424647169129
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=7
# Accuracy rate is 0.7518176135802875
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=10
# Accuracy rate is 0.7582601353203715
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=20
# Accuracy rate is 0.7591209658847913
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=30
# Accuracy rate is 0.7561272493996118
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=50
# Accuracy rate is 0.7642749832768585
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=100
# Accuracy rate is 0.7687874899935301
# Grid search > training the NNet model with learning rate=0.1 and hidden_neurons=200
# Accuracy rate is 0.7779605443519646
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=2
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=4
# Accuracy rate is 0.6719084120143435
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=7
# Accuracy rate is 0.6796120231163163
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=10
# Accuracy rate is 0.6501628450176005
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=20
# Accuracy rate is 0.6542312289589981
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=30
# Accuracy rate is 0.6815255891480518
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=50
# Accuracy rate is 0.6854459321643583
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=100
# Accuracy rate is 0.680390608722352
# Grid search > training the NNet model with learning rate=0.01 and hidden_neurons=200
# Accuracy rate is 0.6915704400653573
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=2
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=4
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=7
# Accuracy rate is 0.5118706889934314
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=10
# Accuracy rate is 0.4908050136526631
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=20
# Accuracy rate is 0.6297277143577765
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=30
# Accuracy rate is 0.5414733910144641
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=50
# Accuracy rate is 0.5501365266309175
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=100
# Accuracy rate is 0.6387527277911197
# Grid search > training the NNet model with learning rate=0.001 and hidden_neurons=200
# Accuracy rate is 0.6518296761741839
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=2
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=4
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=7
# Accuracy rate is 0.45272011492362185
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=10
# Accuracy rate is 0.4173547828184799
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=20
# Accuracy rate is 0.4616409514096786
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=30
# Accuracy rate is 0.5
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=50
# Accuracy rate is 0.4673487515215317
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=100
# Accuracy rate is 0.4147393931418671
# Grid search > training the NNet model with learning rate=0.0001 and hidden_neurons=200
# Accuracy rate is 0.41255167724885133
#
# The Best Hyperparameters are  {'learning_rate': 0.3, 'hidden_neurons': 100}
# Total time taken: 7412.3328058719635 seconds

# %%
train_loss
# Out:
# [tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7082, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7079, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7077, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7072, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7069, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7067, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7064, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7059, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7056, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7053, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7050, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.7047, grad_fn=<BinaryCrossEntropyBackward0>)]

# %%
y_train_pred[:30]

# %%
best_hyperparameters
# Out:
# {'learning_rate': 0.3, 'hidden_neurons': 100}

# %%
input_features = 10
best_learning_rate = best_hyperparameters['learning_rate']
best_hidden_neurons = best_hyperparameters['hidden_neurons']

print(best_learning_rate)
print(best_hidden_neurons)
# Out:
# 0.3
# 100

# %%
train_loss_for_plotting
# Out:
# [tensor(0.6982, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6891, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6844, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6808, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6774, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6742, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6711, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6681, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6652, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6623, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6595, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6568, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6542, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6516, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6491, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6467, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6443, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6419, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6396, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6374, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6352, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6331, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6310, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6290, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6270, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6251, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6232, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6214, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6197, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6180, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6163, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6147, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6132, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6117, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6102, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6088, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6074, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6061, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6035, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6023, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6011, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.6000, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5989, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5978, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5968, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5957, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5948, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5938, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5929, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5919, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5910, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5902, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5893, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5885, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5877, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5869, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5861, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5853, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5845, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5838, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5831, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5824, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5816, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5809, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5803, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5796, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5789, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5782, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5776, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5769, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5763, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5757, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5750, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5744, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5738, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5732, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5726, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5720, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5714, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5708, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5702, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5696, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5690, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5684, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5679, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5673, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5667, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5661, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5656, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5650, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5645, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5639, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5633, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5628, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5622, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5617, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5611, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5606, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5601, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5595, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5590, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5584, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5579, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5574, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5568, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5563, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5558, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5553, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5548, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5542, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5537, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5532, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5527, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5522, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5517, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5512, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5507, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5502, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5497, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5492, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5487, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5482, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5477, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5472, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5468, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5463, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5458, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5453, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5449, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5444, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5439, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5435, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5430, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5426, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5421, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5417, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5412, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5408, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5404, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5399, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5395, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5390, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5386, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5382, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5378, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5374, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5369, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5365, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5361, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5357, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5353, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5349, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5345, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5341, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5337, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5333, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5330, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5326, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5322, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5318, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5315, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5311, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5307, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5304, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5300, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5296, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5293, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5289, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5286, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5283, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5279, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5276, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5272, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5269, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5266, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5262, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5259, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5256, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5253, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5250, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5247, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5243, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5240, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5237, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5234, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5231, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5228, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5225, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5223, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5220, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5217, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5214, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5211, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5208, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5206, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5203, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5200, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5197, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5195, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5192, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5190, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5187, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5184, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5182, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5179, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5177, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5174, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5172, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5169, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5167, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5165, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5162, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5160, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5158, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5155, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5153, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5151, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5148, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5146, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5144, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5142, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5139, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5137, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5135, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5133, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5131, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5129, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5127, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5125, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5123, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5121, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5119, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5117, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5115, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5113, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5111, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5109, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5107, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5105, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5103, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5101, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5099, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5097, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5096, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5094, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5092, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5090, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5088, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5087, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5085, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5083, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5081, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5080, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5078, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5076, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5075, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5073, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5071, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5070, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5068, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5066, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5065, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5063, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5062, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5060, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5058, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5057, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5055, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5054, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5052, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5051, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5049, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5048, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5046, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5045, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5043, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5042, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5040, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5039, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5037, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5036, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5034, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5033, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5032, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5030, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5029, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5027, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5026, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5025, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5023, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5022, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5021, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5019, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5018, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5017, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5015, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5014, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5013, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5011, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5010, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5009, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5007, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5006, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5005, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5003, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5002, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5001, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.5000, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4998, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4997, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4996, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4995, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4993, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4992, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4991, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4990, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4988, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4987, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4986, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4985, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4983, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4982, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4981, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4980, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4979, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4977, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4976, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4975, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4974, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4973, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4971, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4970, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4969, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4968, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4967, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4966, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4964, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4963, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4962, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4961, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4960, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4959, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4957, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4956, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4955, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4954, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4953, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4952, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4950, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4949, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4948, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4947, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4946, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4945, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4944, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4943, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4941, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4940, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4939, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4938, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4937, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4936, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4935, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4934, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4933, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4931, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4930, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4929, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4928, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4927, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4926, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4925, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4924, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4923, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4922, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4921, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4919, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4918, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4917, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4916, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4915, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4914, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4913, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4912, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4911, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4910, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4909, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4907, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4906, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4905, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4904, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4903, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4902, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4901, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4900, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4899, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4898, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4897, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4896, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4894, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4893, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4892, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4891, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4890, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4889, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4888, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4887, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4886, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4885, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4884, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4883, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4881, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4880, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4879, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4878, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4877, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4876, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4875, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4874, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4873, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4872, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4871, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4869, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4868, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4867, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4866, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4865, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4864, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4863, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4862, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4861, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4859, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4858, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4857, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4856, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4855, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4854, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4853, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4852, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4850, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4849, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4848, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4847, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4846, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4845, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4844, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4842, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4841, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4840, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4839, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4838, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4837, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4836, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4834, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4833, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4832, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4831, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4830, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4829, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4827, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4826, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4825, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4824, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4823, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4822, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4821, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4819, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4818, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4817, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4816, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4815, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4814, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4812, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4811, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4810, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4809, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4808, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4807, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4805, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4804, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4803, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4802, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4801, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4800, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4798, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4797, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4796, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4795, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4794, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4793, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4791, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4790, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4789, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4788, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4787, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4785, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4784, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4783, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4782, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4781, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4780, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4778, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4777, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4776, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4775, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4774, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4772, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4771, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4770, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4769, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4768, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4766, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4765, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4764, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4763, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4761, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4760, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4759, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4758, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4757, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4755, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4754, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4753, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4752, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4750, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4749, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4748, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4747, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4746, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4744, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4743, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4742, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4741, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4739, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4738, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4737, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4736, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4734, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4733, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4732, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4731, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4730, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4728, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4727, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4726, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4725, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4723, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4722, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4721, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4720, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4718, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4717, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4716, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4715, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4713, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4712, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4711, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4710, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4708, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4707, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4706, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4705, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4703, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4702, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4701, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4700, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4698, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4697, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4696, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4695, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4693, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4692, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4691, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4689, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4688, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4687, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4686, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4684, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4683, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4682, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4681, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4679, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4678, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4677, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4675, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4674, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4673, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4672, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4670, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4669, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4668, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4666, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4665, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4664, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4663, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4661, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4660, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4659, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4657, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4656, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4655, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4654, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4652, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4651, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4650, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4648, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4647, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4646, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4644, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4643, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4642, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4641, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4639, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4638, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4637, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4635, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4634, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4633, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4631, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4630, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4629, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4628, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4626, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4625, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4624, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4622, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4621, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4620, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4618, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4617, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4616, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4614, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4613, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4612, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4611, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4609, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4608, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4607, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4605, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4604, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4603, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4601, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4600, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4599, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4597, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4596, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4595, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4593, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4592, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4591, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4589, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4588, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4587, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4585, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4584, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4583, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4581, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4580, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4578, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4577, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4576, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4574, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4573, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4572, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4570, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4569, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4568, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4566, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4565, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4563, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4562, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4561, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4559, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4558, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4556, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4555, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4554, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4552, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4551, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4550, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4548, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4547, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4545, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4544, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4543, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4541, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4540, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4538, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4537, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4536, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4534, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4533, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4531, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4530, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4529, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4527, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4526, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4524, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4523, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4521, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4520, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4519, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4517, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4516, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4514, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4513, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4511, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4510, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4509, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4507, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4506, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4504, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4503, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4501, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4500, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4498, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4497, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4496, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4494, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4493, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4491, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4490, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4488, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4487, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4485, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4484, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4482, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4481, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4479, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4478, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4476, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4475, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4473, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4472, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4470, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4469, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4468, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4466, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4465, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4463, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4462, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4460, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4458, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4457, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4455, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4454, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4452, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4451, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4449, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4448, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4446, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4445, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4443, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4442, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4440, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4438, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4437, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4435, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4434, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4432, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4431, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4429, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4428, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4426, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4425, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4423, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4421, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4420, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4418, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4417, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4415, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4414, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4412, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4411, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4409, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4407, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4406, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4404, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4403, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4401, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4400, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4398, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4397, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4395, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4394, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4392, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4391, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4389, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4387, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4386, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4384, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4383, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4381, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4380, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4378, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4377, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4375, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4374, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4372, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4371, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4369, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4368, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4366, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4364, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4363, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4361, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4360, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4358, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4357, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4355, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4354, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4352, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4351, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4349, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4348, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4346, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4345, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4343, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4342, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4340, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4339, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4337, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4336, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4334, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4333, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4331, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4330, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4328, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4327, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4325, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4324, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4322, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4321, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4319, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4318, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4316, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4315, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4313, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4312, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4310, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4309, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4307, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4306, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4304, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4303, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4301, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4300, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4298, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4297, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4295, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4294, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4292, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4291, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4289, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4288, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4285, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4284, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4282, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4281, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4279, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4278, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4276, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4275, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4273, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4272, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4270, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4269, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4267, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4266, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4264, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4263, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4262, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4260, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4259, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4257, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4256, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4254, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4253, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4251, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4250, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4248, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4247, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4246, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4244, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4243, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4241, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4240, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4238, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4237, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4235, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4234, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4233, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4231, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4230, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4228, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4227, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4225, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4224, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4223, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4221, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4220, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4218, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4217, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4215, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4214, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4213, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4211, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4210, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4208, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4207, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4205, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4204, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4203, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4201, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4200, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4198, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4197, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4195, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4194, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4193, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4191, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4190, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4188, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4187, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4186, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4184, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4183, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4181, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4180, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4179, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4177, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4176, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4174, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4173, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4172, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4170, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4169, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4167, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4166, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4165, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4163, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4162, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4160, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4159, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4158, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4156, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4155, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4153, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4152, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4151, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4149, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4148, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4147, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4145, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4144, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4142, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4141, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4140, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4138, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4137, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4136, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4134, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4133, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4132, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4130, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4129, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4128, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4126, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4125, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4124, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4122, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4121, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4119, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4118, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4117, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4115, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4114, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4113, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4111, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4110, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4109, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4107, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4106, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4105, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4103, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4102, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4101, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4099, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4098, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4097, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4096, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4094, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4093, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4092, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4090, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4089, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4088, grad_fn=<BinaryCrossEntropyBackward0>),
#  tensor(0.4086, grad_fn=<BinaryCrossEntropyBackward0>)]

# %%
# Convert from Tensor to list to prepare for plotting with Matplotlib
# Because we can't plot the tensor variables with Matplotlib
train_loss_for_plotting = [tensor_item.item() for tensor_item in train_loss_for_plotting]
val_loss_for_plotting = [tensor_item.item() for tensor_item in val_loss_for_plotting]
print(type(train_loss_for_plotting))
print(type(val_loss_for_plotting))

# Create a numpy list from 1 to the number of epochs
Epochs = np.arange(1, number_of_epochs + 1)
type(Epochs)
# Out:
# <class 'list'>
# <class 'list'>
# numpy.ndarray

# %% [markdown]
# # Data evaluation

# %%
# Now, the type of train_loss_for_plotting and vali_loss_for_plotting are the list.
# We are ready to plot them in Matplotlib
plt.plot(Epochs, train_loss_for_plotting, label='Training Loss')
plt.plot(Epochs, val_loss_for_plotting, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Import the recording performance from MATLAB to plot in Python
import csv
with open('matlab_training_time_bestmodel.csv', 'r') as file1:
    reader1 = csv.reader(file1)
    matlab_training_time_bestmodel = np.array(list(reader1), dtype=float)

with open('matlab_train_loss_for_plotting.csv', 'r') as file2:
    reader2 = csv.reader(file2)
    matlab_train_loss_for_plotting = np.array(list(reader2), dtype=float)
    
with open('matlab_vali_loss_for_plotting.csv', 'r') as file3:
    reader3 = csv.reader(file3)
    matlab_vali_loss_for_plotting = np.array(list(reader3), dtype=float)

# %%
matlab_training_time_bestmodel = matlab_training_time_bestmodel.tolist()[0]
matlab_train_loss_for_plotting = matlab_train_loss_for_plotting.tolist()[0]
matlab_vali_loss_for_plotting = matlab_vali_loss_for_plotting.tolist()[0]

# %%
# Now, the type of train_loss_for_plotting and vali_loss_for_plotting are the list.
# We are ready to plot them in Matplotlib
fig = plt.figure(figsize=(12, 6))
plt.plot(Epochs/5, train_loss_for_plotting, label='Python Training Loss')
plt.plot(Epochs/5, val_loss_for_plotting, label='Python Validation Loss')
plt.plot(Epochs/5, matlab_train_loss_for_plotting, label='MATLAB Training Loss')
plt.plot(Epochs/5, matlab_vali_loss_for_plotting, label='MATLAB Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss of the best-trained model over epochs')
plt.show()

# %%
# Combine the lists into a DataFrame
df_for_heatmap = pd.DataFrame({'Learning Rate': learning_rates_list_heatmap, 'Hidden Neurons': hidden_neurons_list_heatmap, 'Accuracy': accuracy_list_heatmap})

# Pivot the DataFrame to create a matrix suitable for a heatmap
pivoted_heatmap_data = df_for_heatmap.pivot('Hidden Neurons', 'Learning Rate', 'Accuracy')

# Create a heatmap using seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(pivoted_heatmap_data, annot=True, cmap='viridis', fmt=".3f", linewidths=.5)
plt.title('The performance of every combination of hyperparameters')
plt.xlabel('Learning Rate (LR)')
plt.ylabel('Hidden Neurons')
plt.show()

# %%
# Testing data set

best_model.eval()

# From sigmoid probabilities to y labels
y_test_pred = best_model(X_test) > 0.5

# Calculate the accuracy rate
#acc = (y_test_pred.round() == y_test).float().mean()
#acc = float(acc)
#print("Model accuracy: %.2f%%" % (acc*100))

# %%
y_test_pred
# Out:
# tensor([[False],
#         [False],
#         [ True],
#         ...,
#         [False],
#         [ True],
#         [ True]])

# %%
# Calculate = True positive (TP), True Nagative (TN), False Positive (FP), False Nagative (FN)
TP = ((y_test_pred.round() == 1) & (y_test == 1)).sum().item()
TN = ((y_test_pred.round() == 0) & (y_test == 0)).sum().item()
FP = ((y_test_pred.round() == 1) & (y_test == 0)).sum().item()
FN = ((y_test_pred.round() == 0) & (y_test == 1)).sum().item()

# Calculate the confusion matrix 
# Apart from Accuracy rate, we measure Precision, Recall, and F1 score
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print("Precision",precision)
print("Recall",recall)
print("F1 score",f1)
# Out:
# Precision 0.5199600798403193
# Recall 0.6998656687775858
# F1 score 0.5966462167689162

# %%
y_test_pred[0:30]
# Out:
# tensor([[0.0549],
#         [0.1249],
#         [0.7663],
#         [0.3971],
#         [0.3500],
#         [0.0808],
#         [0.1631],
#         [0.0510],
#         [0.3599],
#         [0.6623],
#         [0.1559],
#         [0.3942],
#         [0.2292],
#         [0.5754],
#         [0.2569],
#         [0.5518],
#         [0.9690],
#         [0.5367],
#         [0.9367],
#         [0.5953],
#         [0.0986],
#         [0.4607],
#         [0.1104],
#         [0.1898],
#         [0.2716],
#         [0.1139],
#         [0.7975],
#         [0.1541],
#         [0.8319],
#         [0.1105]], grad_fn=<SliceBackward0>)
